# %% [markdown]
# # Women Graduates - Majors-Jobs

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
graduates_mjrs = pd.read_csv('recent-grad.csv')

# %%
graduates_mjrs.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
graduates_mjrs.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
graduates_mjrs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
# Checking for columns with null values. We can also find from dataframe.info()
graduates_mjrs.columns[graduates_mjrs.isnull().any()]
# Out:
# Index(['Total', 'Men', 'Women', 'ShareWomen'], dtype='object')

# %%
# Excluding row with null values
# size of dataset before exclusion
dsize_bfr = len(graduates_mjrs)
print("before ",dsize_bfr)

graduates_mjrs = graduates_mjrs.dropna()
dsize_aftr = len(graduates_mjrs)
print("after ",dsize_aftr)
# Out:
# before  173
# after  172

# %% [markdown]
# # Scatter plots

# %%
# scatter plot between Men and median salary
men=graduates_mjrs['Men']
median=graduates_mjrs['Median']
full_time=graduates_mjrs['Full_time']
women=graduates_mjrs['Women']
unemp=graduates_mjrs['Unemployed']
emp=graduates_mjrs['Employed']


fig= plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.scatter(men, median, c='red')
ax1.set_xlabel("MEN")
ax1.set_ylabel("Median Salary")
ax1.set_title("Median Salary for men ")


ax2.scatter(women, median, c='green')
ax2.set_xlabel("Women")
ax2.set_ylabel("Median Salary")
ax2.set_title("Median Salary for women ")


ax3.scatter(full_time, median, c='black')
ax3.set_xlabel("fulltime")
ax3.set_ylabel("Median Salary")
ax3.set_title("Median Salary for fulltime emps ")


ax4.scatter(emp, unemp, c='orange')
ax4.set_xlabel("Employed")
ax4.set_ylabel("Unemployed")
ax4.set_title("Employed and unemployed ")

plt.show()

# %% [markdown]
# # Histograms

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]
c=['red','yellow','black','orange','red','yellow','black','orange']
fig = plt.figure(figsize=(20,30))
for r in range(0,8):
    ax = fig.add_subplot(4,2,r+1)
    ax = graduates_mjrs[cols[r]].hist(color=c[r],edgecolor='blue')
    ax.set_xlabel(cols[r])
    ax.set_title(cols[r])
    ax.grid(False)

# %% [markdown]
# # Barplots

# %% [markdown]
# Bar plots to compare the percentages of women (ShareWomen) from the 10 highest paying majors and from the 10 lowest paying majors.

# %%
top_10 = graduates_mjrs.head(10)
bottom_10 = graduates_mjrs.tail(10)

 
fig=plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
row2=[]
row3=[]

for row in top_10['Major']:
    row1=row.replace('ENGINEERING','Eng')
    row1=row1.lower()
    row2.append(row1)
     
ax1.bar(top_10['Major'], top_10['ShareWomen'], color='rgbymc')
ax1.set_xticklabels(row2, rotation=90)
ax1.set_title("Top 10 majors, and women's share") 


ax2.bar(bottom_10['Major'], low_10['ShareWomen'], color='rgbymc')
ax2.set_xticklabels(bottom_10['Major'], rotation=90)
ax2.set_title("Bottom 10 majors, and women's share")


plt.show()

# %% [markdown]
# # Pandas, Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(graduates_mjrs[['Employed', 'Median']], figsize=(6,6))
plt.show()

# %%
scatter_matrix(graduates_mjrs[['Women', 'Median', 'Major']], figsize=(10,10))
plt.show()
